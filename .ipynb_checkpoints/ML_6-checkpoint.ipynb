# %% [markdown]
# МЛ практика 6. Обучение без учителя

# %% [markdown]
# **Задание состоит из следующих частей:**
#
#     Определение обучения без учителя
#     Разбор алгоритмов DBSSCAN, K-means
#     Метрики качества кластеризации
#     Пример полезных задач, которые решает кластеризация
#
# P.S. Некоторые вещи (например PCA, обработка текстовых данных) мы пройдем чуть позже.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Загрузка набора данных
path_to_file: str = 'content/income.csv'
df = pd.read_csv(path_to_file)

# %%
# Создаем копию данных
category_columns: list[str] = df.select_dtypes(include=['object']).columns # собираем колонки помеченные как objects
df.info()
print(category_columns)


# Применяем One-Hot Encoding
df = pd.get_dummies(df, columns=category_columns, drop_first=True)
print(df.columns)
df.education_9th = df.education_9th.astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      30718 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  31978 non-null  object
#  13  income >50K     32561 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country'],
#       dtype='object')
# Index(['age', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'income >50K', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_State-gov',
#        'workclass_Without-pay', 'education_11th', 'education_12th',
#        'education_1st-4th', 'education_5th-6th', 'education_7th-8th',
#        'education_9th', 'education_Assoc-acdm', 'education_Assoc-voc',
#        'education_Bachelors', 'education_Doctorate', 'education_HS-grad',
#        'education_Masters', 'education_Preschool', 'education_Prof-school',
#        'education_Some-college', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent', 'marital-status_Never-married',
#        'marital-status_Separated', 'marital-status_Widowed',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving', 'relationship_Not-in-family',
#        'relationship_Other-relative', 'relationship_Own-child',
#        'relationship_Unmarried', 'relationship_Wife',
#        'race_Asian-Pac-Islander', 'race_Black', 'race_Other', 'race_White',
#        'sex_Male', 'native-country_Canada', 'native-country_China',
#        'native-country_Columbia', 'native-country_Cuba',
#        'native-country_Dominican-Republic', 'native-country_Ecuador',
#        'native-country_El-Salvador', 'native-country_England',
#        'native-country_France', 'native-country_Germany',
#        'native-country_Greece', 'native-country_Guatemala',
#        'native-country_Haiti', 'native-country_Holand-Netherlands',
#        'native-country_Honduras', 'native-country_Hong',
#        'native-country_Hungary', 'native-country_India', 'native-country_Iran',
#        'native-country_Ireland', 'native-country_Italy',
#        'native-country_Jamaica', 'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
#        'native-country_Philippines', 'native-country_Poland',
#        'native-country_Portugal', 'native-country_Puerto-Rico',
#        'native-country_Scotland', 'native-country_South',
#        'native-country_Taiwan', 'native-country_Thailand',
#        'native-country_Trinadad&Tobago', 'native-country_United-States',
#        'native-country_Vietnam', 'native-country_Yugoslavia'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
# Выбираем числовые признаки
numeric_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Инициализируем scaler
scaler = MinMaxScaler()

# Применяем нормализацию
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
df
# Out:
#             age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0      0.301370       0.800000      0.021740           0.0        0.397959
# 1      0.452055       0.800000      0.000000           0.0        0.122449
# 2      0.287671       0.533333      0.000000           0.0        0.397959
# 3      0.493151       0.400000      0.000000           0.0        0.397959
# 4      0.150685       0.800000      0.000000           0.0        0.397959
# ...         ...            ...           ...           ...             ...
# 32556  0.136986       0.733333      0.000000           0.0        0.377551
# 32557  0.315068       0.533333      0.000000           0.0        0.397959
# 32558  0.561644       0.533333      0.000000           0.0        0.397959
# 32559  0.068493       0.533333      0.000000           0.0        0.193878
# 32560  0.479452       0.533333      0.150242           0.0        0.397959
#
#        income >50K  workclass_Local-gov  workclass_Never-worked  \
# 0              0.0                False                   False
# 1              0.0                False                   False
# 2              0.0                False                   False
# 3              0.0                False                   False
# 4              0.0                False                   False
# ...            ...                  ...                     ...
# 32556          0.0                False                   False
# 32557          1.0                False                   False
# 32558          0.0                False                   False
# 32559          0.0                False                   False
# 32560          1.0                False                   False
#
#        workclass_Private  workclass_Self-emp-inc  ...  \
# 0                  False                   False  ...
# 1                  False                   False  ...
# 2                   True                   False  ...
# 3                   True                   False  ...
# 4                   True                   False  ...
# ...                  ...                     ...  ...
# 32556               True                   False  ...
# 32557               True                   False  ...
# 32558               True                   False  ...
# 32559               True                   False  ...
# 32560              False                    True  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 32556                    False                       False
# 32557                    False                       False
# 32558                    False                       False
# 32559                    False                       False
# 32560                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 32556                    False                 False                  False
# 32557                    False                 False                  False
# 32558                    False                 False                  False
# 32559                    False                 False                  False
# 32560                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 32556                    False                           False
# 32557                    False                           False
# 32558                    False                           False
# 32559                    False                           False
# 32560                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                             False                   False
# ...                             ...                     ...
# 32556                          True                   False
# 32557                          True                   False
# 32558                          True                   False
# 32559                          True                   False
# 32560                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 32556                      False
# 32557                      False
# 32558                      False
# 32559                      False
# 32560                      False
#
# [32561 rows x 97 columns]

# %% [markdown]
# О кластеризации и задачи обучения без учителя
# Обучение с учителем
#
# Представьте, что у вас есть список задач с правильными ответами. Например, вам дали примеры: «Это яблоко», «Это груша».
#
# Задача — научиться отличать их, чтобы потом, когда вы увидите новый фрукт, вы смогли правильно его назвать. То есть у вас есть учитель — тот, кто заранее всё объяснил и дал правильные ответы.
# Обучение без учителя
#
# А теперь представьте, что вам дали корзину фруктов, но никто не сказал, как они называются.
#
# Задача — посмотреть на фрукты и найти, что у них общего, например: круглые положить в одну группу, длинные в другую. Тут вы работаете без подсказок и сами решаете, как группировать.
# Разница
#
#     В задачах с учителем есть правильные ответы, и мы обучем алгоритм делать предсказания на основе примеров.
#     В задачах без учителя правильных ответов нет, ищем закономерности и пытаемся найти смысл группировки данные самостоятельно.
#
# Пример:
#
#     С учителем: Мы ищем лучшее вино.
#     Без учителя: Мы пытаемся объеденить вина, чтобы понять по какому принципу они объеденяются.
#
# K-means
#
# K-means — это алгоритм кластеризации, который делит данные на 𝑘 групп (кластеров). Основная идея: найти центры кластеров так, чтобы точки внутри одного кластера были ближе друг к другу, чем к точкам из других кластеров.
#
#     Инициализация: выбираем 𝑘 случайных центров (центроидов).
#     Присвоение точек: каждая точка относится к ближайшему центру. Обновление центров: пересчитываем центры кластеров как среднее всех точек в кластере.
#     Повторяем шаги 2–3, пока центры не перестанут меняться или не достигнем максимального числа итераций.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

def interactive_kmeans_visualization(X, max_clusters=10, max_iterations=50):

    # преобразуем X в numpy array
    if isinstance(X, pd.DataFrame):
        X = X.values

    def plot_kmeans_iteration(X, centroids, labels=None, step=0):
        clear_output(wait=True)
        plt.figure(figsize=(8, 6))
        if labels is not None:
            plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30, alpha=0.6)
        else:
            plt.scatter(X[:, 0], X[:, 1], s=30, alpha=0.6)
        plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=100, label='Centroids')
        plt.title(f'K-means Iteration {step}')
        plt.legend()
        plt.show()

    def k_means_interactive(X, k, max_iters):
        np.random.seed(42)
        centroids = X[np.random.choice(X.shape[0], k, replace=False)]
        for step in range(max_iters):
            distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
            labels = np.argmin(distances, axis=1)
            plot_kmeans_iteration(X, centroids, labels, step)
            new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(k)])
            if np.all(centroids == new_centroids):
                break
            centroids = new_centroids

    def run_kmeans(k, max_iters):
        k_means_interactive(X, k, max_iters)

    k_slider = widgets.IntSlider(value=3, min=2, max=max_clusters, step=1, description='Clusters (k):')
    iter_slider = widgets.IntSlider(value=10, min=1, max=max_iterations, step=1, description='Max Iterations:')

    interactive_plot = widgets.interactive(run_kmeans, k=k_slider, max_iters=iter_slider)
    display(interactive_plot)

# Берем датасет и визуализируем K-means
interactive_kmeans_visualization(df[:100])
# Out:
# interactive(children=(IntSlider(value=3, description='Clusters (k):', max=10, min=2), IntSlider(value=10, desc…

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Определяем количество кластеров k
k = 3  # Вы можете изменить это значение в соответствии с вашими данными

# Создаем и обучаем модель KMeans
kmeans = KMeans(n_clusters=k, random_state=42)
labels = kmeans.fit_predict(df)
centroids = kmeans.cluster_centers_

# Добавляем метки кластеров в исходный DataFrame
df_k_means = df.copy()
df_k_means['Cluster'] = labels

# Вывод статистики по кластерам для каждого признака
print("Статистика по кластерам:")
for column in df.columns:
    print(f"\nСтатистика для признака '{column}':")
    cluster_stats = df_k_means.groupby('Cluster')[column].agg(['mean', 'std', 'min', 'max'])
    print(cluster_stats)

# Вычисление коэффициента силуэта
if k > 1:
    silhouette_avg = silhouette_score(df, labels)
    print(f"\nКоэффициент силуэта для k={k}: {silhouette_avg:.4f}")
else:
    print("\nКоэффициент силуэта не определен для k=1")
# Out:
# Статистика по кластерам:
#
# Статистика для признака 'age':
#              mean       std       min  max
# Cluster
# 0        0.233909  0.185136  0.000000  1.0
# 1        0.407482  0.170478  0.013699  1.0
# 2        0.334299  0.155000  0.000000  1.0
#
# Статистика для признака 'education-num':
#              mean       std  min  max
# Cluster
# 0        0.587859  0.159466  0.0  1.0
# 1        0.651716  0.186054  0.0  1.0
# 2        0.607625  0.176973  0.0  1.0
#
# Статистика для признака 'capital-gain':
#              mean       std  min  max
# Cluster
# 0        0.003808  0.036722  0.0  1.0
# 1        0.022471  0.113354  0.0  1.0
# 2        0.015698  0.088684  0.0  1.0
#
# Статистика для признака 'capital-loss':
#              mean       std  min       max
# Cluster
# 0        0.012556  0.073666  0.0  1.000000
# 1        0.030851  0.114599  0.0  0.648301
# 2        0.026377  0.104741  0.0  0.648301
#
# Статистика для признака 'hours-per-week':
#              mean       std       min  max
# Cluster
# 0        0.374381  0.123038  0.000000  1.0
# 1        0.432524  0.148221  0.000000  1.0
# 2        0.432365  0.103488  0.010204  1.0
#
# Статистика для признака 'income >50K':
#              mean       std  min  max
# Cluster
# 0        0.047772  0.213289  0.0  1.0
# 1        0.461604  0.498566  0.0  1.0
# 2        0.438801  0.496266  0.0  1.0
#
# Статистика для признака 'workclass_Local-gov':
#              mean       std    min    max
# Cluster
# 0        0.056506  0.230904  False   True
# 1        0.194020  0.395478  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'workclass_Never-worked':
#              mean       std    min    max
# Cluster
# 0        0.000357  0.018879  False   True
# 1        0.000170  0.013034  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'workclass_Private':
#              mean       std    min    max
# Cluster
# 0        0.763577  0.424898  False   True
# 1        0.000000  0.000000  False  False
# 2        1.000000  0.000000   True   True
#
# Статистика для признака 'workclass_Self-emp-inc':
#              mean       std    min    max
# Cluster
# 0        0.012121  0.109430  False   True
# 1        0.154944  0.361882  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'workclass_Self-emp-not-inc':
#              mean       std    min    max
# Cluster
# 0        0.031729  0.175283  False   True
# 1        0.340979  0.474078  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'workclass_State-gov':
#              mean       std    min    max
# Cluster
# 0        0.038622  0.192697  False   True
# 1        0.110092  0.313031  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'workclass_Without-pay':
#              mean       std    min    max
# Cluster
# 0        0.000357  0.018879  False   True
# 1        0.001359  0.036845  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'education_11th':
#              mean       std    min   max
# Cluster
# 0        0.048247  0.214294  False  True
# 1        0.015460  0.123385  False  True
# 2        0.027628  0.163914  False  True
#
# Статистика для признака 'education_12th':
#              mean       std    min   max
# Cluster
# 0        0.017766  0.132103  False  True
# 1        0.007645  0.087110  False  True
# 2        0.009040  0.094654  False  True
#
# Статистика для признака 'education_1st-4th':
#              mean       std    min   max
# Cluster
# 0        0.004932  0.070055  False  True
# 1        0.003058  0.055220  False  True
# 2        0.006805  0.082218  False  True
#
# Статистика для признака 'education_5th-6th':
#              mean       std    min   max
# Cluster
# 0        0.009329  0.096136  False  True
# 1        0.008155  0.089943  False  True
# 2        0.013002  0.113286  False  True
#
# Статистика для признака 'education_7th-8th':
#              mean       std    min   max
# Cluster
# 0        0.016518  0.127461  False  True
# 1        0.024805  0.155542  False  True
# 2        0.022550  0.148470  False  True
#
# Статистика для признака 'education_9th':
#              mean       std  min  max
# Cluster
# 0        0.016578  0.127686  0.0  1.0
# 1        0.012232  0.109931  0.0  1.0
# 2        0.016557  0.127609  0.0  1.0
#
# Статистика для признака 'education_Assoc-acdm':
#              mean       std    min   max
# Cluster
# 0        0.034284  0.181963  False  True
# 1        0.032960  0.178546  False  True
# 2        0.030066  0.170778  False  True
#
# Статистика для признака 'education_Assoc-voc':
#              mean       std    min   max
# Cluster
# 0        0.039632  0.195098  False  True
# 1        0.037717  0.190526  False  True
# 2        0.050076  0.218113  False  True
#
# Статистика для признака 'education_Bachelors':
#              mean       std    min   max
# Cluster
# 0        0.142365  0.349434  False  True
# 1        0.199117  0.399370  False  True
# 2        0.181513  0.385463  False  True
#
# Статистика для признака 'education_Doctorate':
#              mean       std    min   max
# Cluster
# 0        0.005704  0.075312  False  True
# 1        0.031940  0.175856  False  True
# 2        0.013103  0.113722  False  True
#
# Статистика для признака 'education_HS-grad':
#              mean       std    min   max
# Cluster
# 0        0.323886  0.467971  False  True
# 1        0.289840  0.453727  False  True
# 2        0.339665  0.473619  False  True
#
# Статистика для признака 'education_Masters':
#              mean       std    min   max
# Cluster
# 0        0.037374  0.189682  False  True
# 1        0.093612  0.291313  False  True
# 2        0.055155  0.228294  False  True
#
# Статистика для признака 'education_Preschool':
#              mean       std    min   max
# Cluster
# 0        0.001783  0.042184  False  True
# 1        0.000849  0.029136  False  True
# 2        0.001625  0.040283  False  True
#
# Статистика для признака 'education_Prof-school':
#              mean       std    min   max
# Cluster
# 0        0.008021  0.089205  False  True
# 1        0.046551  0.210693  False  True
# 2        0.016963  0.129139  False  True
#
# Статистика для признака 'education_Some-college':
#              mean       std    min   max
# Cluster
# 0        0.260012  0.438654  False  True
# 1        0.177710  0.382301  False  True
# 2        0.189843  0.392196  False  True
#
# Статистика для признака 'marital-status_Married-AF-spouse':
#              mean       std    min   max
# Cluster
# 0        0.000772  0.027783  False  True
# 1        0.000680  0.026062  False  True
# 2        0.000609  0.024681  False  True
#
# Статистика для признака 'marital-status_Married-civ-spouse':
#              mean       std    min   max
# Cluster
# 0        0.000059  0.007708  False  True
# 1        0.890928  0.311756  False  True
# 2        0.988421  0.106989  False  True
#
# Статистика для признака 'marital-status_Married-spouse-absent':
#              mean       std    min   max
# Cluster
# 0        0.022044  0.146831  False  True
# 1        0.006456  0.080096  False  True
# 2        0.000914  0.030223  False  True
#
# Статистика для признака 'marital-status_Never-married':
#              mean       std    min    max
# Cluster
# 0        0.633214  0.481942  False   True
# 1        0.004417  0.066321  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'marital-status_Separated':
#              mean       std    min   max
# Cluster
# 0        0.056209  0.230332  False  True
# 1        0.011723  0.107644  False  True
# 2        0.001016  0.031856  False  True
#
# Статистика для признака 'marital-status_Widowed':
#              mean       std    min   max
# Cluster
# 0        0.054189  0.226397  False  True
# 1        0.011723  0.107644  False  True
# 2        0.001219  0.034893  False  True
#
# Статистика для признака 'occupation_Armed-Forces':
#              mean       std    min    max
# Cluster
# 0        0.000357  0.018879  False   True
# 1        0.000510  0.022572  False   True
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'occupation_Craft-repair':
#              mean       std    min   max
# Cluster
# 0        0.082650  0.275361  False  True
# 1        0.123174  0.328664  False  True
# 2        0.201422  0.401083  False  True
#
# Статистика для признака 'occupation_Exec-managerial':
#              mean       std    min   max
# Cluster
# 0        0.085502  0.279636  False  True
# 1        0.182467  0.386262  False  True
# 2        0.157745  0.364520  False  True
#
# Статистика для признака 'occupation_Farming-fishing':
#              mean       std    min   max
# Cluster
# 0        0.022460  0.148178  False  True
# 1        0.071526  0.257723  False  True
# 2        0.019807  0.139344  False  True
#
# Статистика для признака 'occupation_Handlers-cleaners':
#              mean       std    min   max
# Cluster
# 0        0.053179  0.224397  False  True
# 1        0.008665  0.092688  False  True
# 2        0.043068  0.203020  False  True
#
# Статистика для признака 'occupation_Machine-op-inspct':
#              mean       std    min   max
# Cluster
# 0        0.059715  0.236965  False  True
# 1        0.009514  0.097083  False  True
# 2        0.095582  0.294031  False  True
#
# Статистика для признака 'occupation_Other-service':
#              mean       std    min   max
# Cluster
# 0        0.152288  0.359310  False  True
# 1        0.034998  0.183791  False  True
# 2        0.053428  0.224897  False  True
#
# Статистика для признака 'occupation_Priv-house-serv':
#              mean       std    min    max
# Cluster
# 0        0.007903  0.088547  False   True
# 1        0.000000  0.000000  False  False
# 2        0.001625  0.040283  False   True
#
# Статистика для признака 'occupation_Prof-specialty':
#              mean       std    min   max
# Cluster
# 0        0.109447  0.312209  False  True
# 1        0.190962  0.393092  False  True
# 2        0.119248  0.324097  False  True
#
# Статистика для признака 'occupation_Protective-serv':
#              mean       std    min   max
# Cluster
# 0        0.014023  0.117587  False  True
# 1        0.054196  0.226424  False  True
# 2        0.009548  0.097251  False  True
#
# Статистика для признака 'occupation_Sales':
#              mean       std    min   max
# Cluster
# 0        0.113785  0.317559  False  True
# 1        0.094801  0.292965  False  True
# 2        0.119553  0.324455  False  True
#
# Статистика для признака 'occupation_Tech-support':
#              mean       std    min   max
# Cluster
# 0        0.030303  0.171425  False  True
# 1        0.016650  0.127966  False  True
# 2        0.032504  0.177343  False  True
#
# Статистика для признака 'occupation_Transport-moving':
#              mean       std    min   max
# Cluster
# 0        0.033749  0.180588  False  True
# 1        0.043663  0.204361  False  True
# 2        0.078415  0.268838  False  True
#
# Статистика для признака 'relationship_Not-in-family':
#              mean       std    min   max
# Cluster
# 0        0.468806  0.499041  False  True
# 1        0.062861  0.242733  False  True
# 2        0.004571  0.067457  False  True
#
# Статистика для признака 'relationship_Other-relative':
#              mean       std    min   max
# Cluster
# 0        0.048010  0.213793  False  True
# 1        0.011043  0.104513  False  True
# 2        0.010970  0.104167  False  True
#
# Статистика для признака 'relationship_Own-child':
#              mean       std    min   max
# Cluster
# 0        0.293167  0.455228  False  True
# 1        0.010194  0.100456  False  True
# 2        0.007517  0.086376  False  True
#
# Статистика для признака 'relationship_Unmarried':
#              mean       std    min   max
# Cluster
# 0        0.189364  0.391809  False  True
# 1        0.034659  0.182929  False  True
# 2        0.005587  0.074538  False  True
#
# Статистика для признака 'relationship_Wife':
#              mean       std    min   max
# Cluster
# 0        0.000475  0.021798  False  True
# 1        0.096160  0.294836  False  True
# 2        0.100965  0.301298  False  True
#
# Статистика для признака 'race_Asian-Pac-Islander':
#              mean       std    min   max
# Cluster
# 0        0.030541  0.172075  False  True
# 1        0.031940  0.175856  False  True
# 2        0.034231  0.181830  False  True
#
# Статистика для признака 'race_Black':
#              mean       std    min   max
# Cluster
# 0        0.134046  0.340712  False  True
# 1        0.051648  0.221334  False  True
# 2        0.057288  0.232404  False  True
#
# Статистика для признака 'race_Other':
#              mean       std    min   max
# Cluster
# 0        0.009685  0.097938  False  True
# 1        0.004417  0.066321  False  True
# 2        0.008329  0.090888  False  True
#
# Статистика для признака 'race_White':
#              mean       std    min   max
# Cluster
# 0        0.814557  0.388668  False  True
# 1        0.903160  0.295765  False  True
# 2        0.892941  0.309204  False  True
#
# Статистика для признака 'sex_Male':
#              mean       std    min   max
# Cluster
# 0        0.464231  0.498734  False  True
# 1        0.883112  0.321314  False  True
# 2        0.891722  0.310747  False  True
#
# Статистика для признака 'native-country_Canada':
#              mean       std    min   max
# Cluster
# 0        0.003327  0.057589  False  True
# 1        0.004417  0.066321  False  True
# 2        0.003961  0.062818  False  True
#
# Статистика для признака 'native-country_China':
#              mean       std    min   max
# Cluster
# 0        0.001485  0.038514  False  True
# 1        0.003058  0.055220  False  True
# 2        0.003250  0.056922  False  True
#
# Статистика для признака 'native-country_Columbia':
#              mean       std    min   max
# Cluster
# 0        0.002317  0.048084  False  True
# 1        0.001359  0.036845  False  True
# 2        0.001219  0.034893  False  True
#
# Статистика для признака 'native-country_Cuba':
#              mean       std    min   max
# Cluster
# 0        0.002614  0.051066  False  True
# 1        0.003398  0.058197  False  True
# 2        0.003149  0.056029  False  True
#
# Статистика для признака 'native-country_Dominican-Republic':
#              mean       std    min   max
# Cluster
# 0        0.002911  0.053881  False  True
# 1        0.000849  0.029136  False  True
# 2        0.001625  0.040283  False  True
#
# Статистика для признака 'native-country_Ecuador':
#              mean       std    min   max
# Cluster
# 0        0.000772  0.027783  False  True
# 1        0.000340  0.018432  False  True
# 2        0.001320  0.036316  False  True
#
# Статистика для признака 'native-country_El-Salvador':
#              mean       std    min   max
# Cluster
# 0        0.003981  0.062971  False  True
# 1        0.001869  0.043193  False  True
# 2        0.002844  0.053257  False  True
#
# Статистика для признака 'native-country_England':
#              mean       std    min   max
# Cluster
# 0        0.002911  0.053881  False  True
# 1        0.002718  0.052071  False  True
# 2        0.002539  0.050331  False  True
#
# Статистика для признака 'native-country_France':
#              mean       std    min   max
# Cluster
# 0        0.000891  0.029842  False  True
# 1        0.000849  0.029136  False  True
# 2        0.000914  0.030223  False  True
#
# Статистика для признака 'native-country_Germany':
#              mean       std    min   max
# Cluster
# 0        0.004100  0.063900  False  True
# 1        0.003568  0.059629  False  True
# 2        0.004774  0.068932  False  True
#
# Статистика для признака 'native-country_Greece':
#              mean       std    min   max
# Cluster
# 0        0.000416  0.020391  False  True
# 1        0.001529  0.039077  False  True
# 2        0.001320  0.036316  False  True
#
# Статистика для признака 'native-country_Guatemala':
#              mean       std    min   max
# Cluster
# 0        0.002911  0.053881  False  True
# 1        0.000170  0.013034  False  True
# 2        0.001422  0.037685  False  True
#
# Статистика для признака 'native-country_Haiti':
#              mean       std    min   max
# Cluster
# 0        0.001723  0.041476  False  True
# 1        0.000340  0.018432  False  True
# 2        0.001320  0.036316  False  True
#
# Статистика для признака 'native-country_Holand-Netherlands':
#              mean       std    min    max
# Cluster
# 0        0.000059  0.007708  False   True
# 1        0.000000  0.000000  False  False
# 2        0.000000  0.000000  False  False
#
# Статистика для признака 'native-country_Honduras':
#              mean       std    min   max
# Cluster
# 0        0.000594  0.024369  False  True
# 1        0.000340  0.018432  False  True
# 2        0.000102  0.010078  False  True
#
# Статистика для признака 'native-country_Hong':
#              mean       std    min   max
# Cluster
# 0        0.000416  0.020391  False  True
# 1        0.000680  0.026062  False  True
# 2        0.000914  0.030223  False  True
#
# Статистика для признака 'native-country_Hungary':
#              mean       std    min   max
# Cluster
# 0        0.000416  0.020391  False  True
# 1        0.000510  0.022572  False  True
# 2        0.000305  0.017455  False  True
#
# Статистика для признака 'native-country_India':
#              mean       std    min   max
# Cluster
# 0        0.001961  0.044239  False  True
# 1        0.003738  0.061027  False  True
# 2        0.004571  0.067457  False  True
#
# Статистика для признака 'native-country_Iran':
#              mean       std    min   max
# Cluster
# 0        0.000891  0.029842  False  True
# 1        0.002209  0.046948  False  True
# 2        0.001524  0.039006  False  True
#
# Статистика для признака 'native-country_Ireland':
#              mean       std    min   max
# Cluster
# 0        0.000951  0.030819  False  True
# 1        0.000170  0.013034  False  True
# 2        0.000711  0.026657  False  True
#
# Статистика для признака 'native-country_Italy':
#              mean       std    min   max
# Cluster
# 0        0.001307  0.036133  False  True
# 1        0.003568  0.059629  False  True
# 2        0.003047  0.055120  False  True
#
# Статистика для признака 'native-country_Jamaica':
#              mean       std    min   max
# Cluster
# 0        0.003327  0.057589  False  True
# 1        0.001189  0.034468  False  True
# 2        0.001828  0.042722  False  True
#
# Статистика для признака 'native-country_Japan':
#              mean       std    min   max
# Cluster
# 0        0.001723  0.041476  False  True
# 1        0.001359  0.036845  False  True
# 2        0.002539  0.050331  False  True
#
# Статистика для признака 'native-country_Laos':
#              mean       std    min   max
# Cluster
# 0        0.000416  0.020391  False  True
# 1        0.000510  0.022572  False  True
# 2        0.000813  0.028496  False  True
#
# Статистика для признака 'native-country_Mexico':
#              mean       std    min   max
# Cluster
# 0        0.019133  0.136995  False  True
# 1        0.010024  0.099624  False  True
# 2        0.026612  0.160956  False  True
#
# Статистика для признака 'native-country_Nicaragua':
#              mean       std    min   max
# Cluster
# 0        0.001188  0.034453  False  True
# 1        0.000849  0.029136  False  True
# 2        0.000914  0.030223  False  True
#
# Статистика для признака 'native-country_Outlying-US(Guam-USVI-etc)':
#              mean       std    min   max
# Cluster
# 0        0.000654  0.025558  False  True
# 1        0.000170  0.013034  False  True
# 2        0.000203  0.014252  False  True
#
# Статистика для признака 'native-country_Peru':
#              mean       std    min   max
# Cluster
# 0        0.001188  0.034453  False  True
# 1        0.000340  0.018432  False  True
# 2        0.000914  0.030223  False  True
#
# Статистика для признака 'native-country_Philippines':
#              mean       std    min   max
# Cluster
# 0        0.005585  0.074528  False  True
# 1        0.004757  0.068813  False  True
# 2        0.007720  0.087526  False  True
#
# Статистика для признака 'native-country_Poland':
#              mean       std    min   max
# Cluster
# 0        0.001604  0.040022  False  True
# 1        0.001189  0.034468  False  True
# 2        0.002641  0.051325  False  True
#
# Статистика для признака 'native-country_Portugal':
#              mean       std    min   max
# Cluster
# 0        0.000891  0.029842  False  True
# 1        0.001189  0.034468  False  True
# 2        0.001524  0.039006  False  True
#
# Статистика для признака 'native-country_Puerto-Rico':
#              mean       std    min   max
# Cluster
# 0        0.003981  0.062971  False  True
# 1        0.002548  0.050422  False  True
# 2        0.003250  0.056922  False  True
#
# Статистика для признака 'native-country_Scotland':
#              mean       std    min   max
# Cluster
# 0        0.000357  0.018879  False  True
# 1        0.000340  0.018432  False  True
# 2        0.000406  0.020154  False  True
#
# Статистика для признака 'native-country_South':
#              mean       std    min   max
# Cluster
# 0        0.002317  0.048084  False  True
# 1        0.004077  0.063730  False  True
# 2        0.001727  0.041521  False  True
#
# Статистика для признака 'native-country_Taiwan':
#              mean       std    min   max
# Cluster
# 0        0.001367  0.036943  False  True
# 1        0.002379  0.048716  False  True
# 2        0.001422  0.037685  False  True
#
# Статистика для признака 'native-country_Thailand':
#              mean       std    min   max
# Cluster
# 0        0.000594  0.024369  False  True
# 1        0.000849  0.029136  False  True
# 2        0.000305  0.017455  False  True
#
# Статистика для признака 'native-country_Trinadad&Tobago':
#              mean       std    min   max
# Cluster
# 0        0.000594  0.024369  False  True
# 1        0.000340  0.018432  False  True
# 2        0.000711  0.026657  False  True
#
# Статистика для признака 'native-country_United-States':
#              mean       std    min   max
# Cluster
# 0        0.898099  0.302528  False  True
# 1        0.910805  0.285049  False  True
# 2        0.883088  0.321332  False  True
#
# Статистика для признака 'native-country_Vietnam':
#              mean       std    min   max
# Cluster
# 0        0.002436  0.049298  False  True
# 1        0.001189  0.034468  False  True
# 2        0.001930  0.043891  False  True
#
# Статистика для признака 'native-country_Yugoslavia':
#              mean       std    min   max
# Cluster
# 0        0.000238  0.015415  False  True
# 1        0.000510  0.022572  False  True
# 2        0.000914  0.030223  False  True
#
# Коэффициент силуэта для k=3: 0.0909
